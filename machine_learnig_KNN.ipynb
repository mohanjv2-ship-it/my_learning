# %%
# import ssl
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# Disable SSL certificate verification
# ssl._create_default_https_context = ssl._create_unverified_context

df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%203/data/teleCust1000t.csv')
print(df)

y = df['custcat'].values
y[0:5]

x = df[['region', 'tenure','age', 'marital', 'address', 'income', 'ed', 'employ','retire',
        'gender', 'reside']] .values  #.astype(float)

#X = StandardScaler().fit(X).transform(X.astype(float))

std_obj = MinMaxScaler()
x = std_obj.fit_transform(x)
x = x.astype(float)
print(x[0:5])

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, random_state=4)
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)

model = KNeighborsRegressor(n_neighbors=3)
model.fit(x_train, y_train)
prediction = model.predict(x_test)
print(prediction)

model_evaluation = model.score(x_test, y_test)
print(model_evaluation)

model_evaluation_r2 = r2_score(y_test, prediction)
print(model_evaluation_r2)
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9    64.0   4       5     0.0
# 1         3      11   33        1        7   136.0   5       5     0.0
# 2         3      68   52        1       24   116.0   1      29     0.0
# 3         2      33   33        0       12    33.0   2       0     0.0
# 4         2      23   30        1        9    30.0   1       2     0.0
# ..      ...     ...  ...      ...      ...     ...  ..     ...     ...
# 995       3      10   39        0        0    27.0   3       0     0.0
# 996       1       7   34        0        2    22.0   5       5     0.0
# 997       3      67   59        0       40   944.0   5      33     0.0
# 998       3      70   49        0       18    87.0   2      22     0.0
# 999       3      50   36        1        7    39.0   3       3     0.0
#
#      gender  reside  custcat
# 0         0       2        1
# 1         0       6        4
# ...

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, f1_score, confusion_matrix, precision_score

df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%203/data/teleCust1000t.csv')
print(df)

y = df['custcat'].values
y[0:5]

x = df[['region', 'tenure','age', 'marital', 'address', 'income', 'ed', 'employ','retire',
        'gender', 'reside']] .values  #.astype(float)

#X = StandardScaler().fit(X).transform(X.astype(float))

std_obj = MinMaxScaler()
x = std_obj.fit_transform(x)
x = x.astype(float)
print(x[0:5])

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, random_state=4)
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)

model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train, y_train)
prediction = model.predict(x_test)
print(prediction)

model_evaluation = model.score(x_test, y_test)
print(model_evaluation)

model_evaluation_f1 = f1_score(y_test, prediction, average='weighted')
print(model_evaluation_f1)
model_evaluation_precision = precision_score(y_test, prediction, average='weighted')
print(model_evaluation_precision)
model_evaluation_acc = accuracy_score(y_test, prediction)
print(model_evaluation_acc)
model_evaluation_recall = recall_score(y_test, prediction, average='weighted')
print(model_evaluation_recall)
model_evaluation_cmat = confusion_matrix(y_test, prediction)
print(model_evaluation_cmat)
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9    64.0   4       5     0.0
# 1         3      11   33        1        7   136.0   5       5     0.0
# 2         3      68   52        1       24   116.0   1      29     0.0
# 3         2      33   33        0       12    33.0   2       0     0.0
# 4         2      23   30        1        9    30.0   1       2     0.0
# ..      ...     ...  ...      ...      ...     ...  ..     ...     ...
# 995       3      10   39        0        0    27.0   3       0     0.0
# 996       1       7   34        0        2    22.0   5       5     0.0
# 997       3      67   59        0       40   944.0   5      33     0.0
# 998       3      70   49        0       18    87.0   2      22     0.0
# 999       3      50   36        1        7    39.0   3       3     0.0
#
#      gender  reside  custcat
# 0         0       2        1
# 1         0       6        4
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier

iris = load_iris()

x = iris.data
y = iris.target

knn = KNeighborsClassifier()

grid = {'n_neighbors': [3,5,7,9,11]}

search = GridSearchCV(knn, grid, cv=5)
search.fit(x,y)

print("Best hyperparameters:", search.best_params_)
print("Best score:", search.best_score_)
print("Best index:", search.best_index_)
print("Best estimator:", search.best_estimator_)
# Out:
# Best hyperparameters: {'n_neighbors': 7}
# Best score: 0.9800000000000001
# Best index: 2
# Best estimator: KNeighborsClassifier(n_neighbors=7)
